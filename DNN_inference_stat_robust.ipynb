# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
sigma = [1, 2, 3, 4, 5]
bt1_bb1_tb2 = [444390, 670450, 800440, 875320, 875210]
bt1_bb1_tb1 = [341360, 273120, 192020, 124180, 124270]
bt0_bb1_tb3 = [164890,  48860,   7030,	  490,	  500]
bt0_bb1_tb2 = [ 49360,	 7580,	  500,	   10,	   20]

# %%
font_set_size = 35
font_set_size2 = 20
line_thickness = 4
fig = plt.figure(figsize=(15,10)) #empty figure with nothing
plt.plot(sigma, bt1_bb1_tb2, '-o', markersize = 20, label="1[bt]-1[bb]-2[tb]")
plt.plot(sigma, bt1_bb1_tb1, '-s', markersize = 20, label="1[bt]-1[bb]-1[tb]")
plt.plot(sigma, bt0_bb1_tb3, '-v', markersize = 20, label="0[bt]-1[bb]-3[tb]")
plt.plot(sigma, bt0_bb1_tb2, '-x', markersize = 20, label="0[bt]-1[bb]-2[tb]")

tick_posx = sigma
tick_labx = ['$1\sigma$', '$2\sigma$', '$3\sigma$', '$4\sigma$', '$5\sigma$']

tick_posy = [10**6/4*1, 10**6/4*2, 10**6/4*3, 10**6]
tick_laby = ['2.5', '5.0', '7.5', '10']


plt.ylabel('DNN inference count (x$10^5$)', fontsize=font_set_size)
plt.yticks(tick_posy, tick_laby, fontsize=font_set_size)

plt.xlabel('Error bar interpretation', fontsize=font_set_size)
plt.xticks(tick_posx, tick_labx, fontsize=font_set_size)

plt.legend(loc='center right', fontsize = font_set_size)

plt.tight_layout()

plt.yticks(fontsize=font_set_size)
plt.xticks(fontsize=font_set_size)
plt.grid(True)

plt.show()
